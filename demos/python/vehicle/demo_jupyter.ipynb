# %%
# Simple jupyter notebook demo
# Meant to demonstrate Python API
# PLEASE DON'T CHANGE
# -----------------------------------------------------------------

# %%
# Use the interactive backend so we can control the car
# %matplotlib widget

# Import the simulator
import wa_simulator as wa

# Simulation config
step_size = 3e-3
render_step_size = 1e-1

# %%
# Create the system
sys = wa.WASystem(step_size=1e-3)

# Create an environment using a premade environment description
env_filename = wa.WASimpleEnvironment.EGP_ENV_MODEL_FILE
env = wa.WASimpleEnvironment(env_filename, sys)

# Create an vehicle using a premade vehicle description
veh_filename = wa.WALinearKinematicBicycle.GO_KART_MODEL_FILE
veh = wa.WALinearKinematicBicycle(veh_filename)

# Visualize the simulation using matplotlib
vis = wa.WAMatplotlibJupyterVisualization(veh, sys)

# Create a controller
ctr = wa.WASimpleController(sys)

# Instantiate the simulation manager
sim = wa.WASimulation(sys, env, veh, vis, ctr)

# Run the simulation
while sim.is_ok():
    time = sys.get_sim_time()

    sim.synchronize(time)
    sim.advance(step_size)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-1fe386166e19> in <module>
#      24
#      25     sim.synchronize(time)
# ---> 26     sim.advance(step_size)
#
# ~/Code/wa/wa_simulator/wa_simulator/simulation.py in advance(self, step)
#      99         if self.visualization:
#     100             # Will advance the visualization if necessary
# --> 101             self.visualization.advance(step)
#     102
#     103     def run(self):
#
# ~/Code/wa/wa_simulator/wa_simulator/visualization.py in advance(self, step)
#     831             self.update()
#     832
# --> 833             display(self.plotter.fig)
#     834             clear_output(wait=True)
#     835
#
# /usr/local/anaconda3/envs/wa-dev/lib/python3.8/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/anaconda3/envs/wa-dev/lib/python3.8/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/anaconda3/envs/wa-dev/lib/python3.8/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/anaconda3/envs/wa-dev/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/anaconda3/envs/wa-dev/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/anaconda3/envs/wa-dev/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# /usr/local/anaconda3/envs/wa-dev/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2193                         self.figure.draw(renderer)
#    2194
# -> 2195                     bbox_inches = self.figure.get_tightbbox(
#    2196                         renderer, bbox_extra_artists=bbox_extra_artists)
#    2197                     if pad_inches is None:
#
# /usr/local/anaconda3/envs/wa-dev/lib/python3.8/site-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2504
#    2505         for a in artists:
# -> 2506             bbox = a.get_tightbbox(renderer)
#    2507             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2508                 bb.append(bbox)
#
# /usr/local/anaconda3/envs/wa-dev/lib/python3.8/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4160             if self.yaxis.get_visible():
#    4161                 try:
# -> 4162                     bb_yaxis = self.yaxis.get_tightbbox(
#    4163                         renderer, for_layout_only=for_layout_only)
#    4164                 except TypeError:
#
# /usr/local/anaconda3/envs/wa-dev/lib/python3.8/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1107             return
#    1108
# -> 1109         ticks_to_draw = self._update_ticks()
#    1110
#    1111         self._update_label_position(renderer)
#
# /usr/local/anaconda3/envs/wa-dev/lib/python3.8/site-packages/matplotlib/axis.py in _update_ticks(self)
#    1027             tick.set_label1(label)
#    1028             tick.set_label2(label)
# -> 1029         minor_locs = self.get_minorticklocs()
#    1030         minor_labels = self.minor.formatter.format_ticks(minor_locs)
#    1031         minor_ticks = self.get_minor_ticks(len(minor_locs))
#
# /usr/local/anaconda3/envs/wa-dev/lib/python3.8/site-packages/matplotlib/axis.py in get_minorticklocs(self)
#    1286         """Return this Axis' minor tick locations in data coordinates."""
#    1287         # Remove minor ticks duplicating major ticks.
# -> 1288         major_locs = self.major.locator()
#    1289         minor_locs = self.minor.locator()
#    1290         transform = self._scale.get_transform()
#
# /usr/local/anaconda3/envs/wa-dev/lib/python3.8/site-packages/matplotlib/ticker.py in __call__(self)
#    2274     def __call__(self):
#    2275         vmin, vmax = self.axis.get_view_interval()
# -> 2276         return self.tick_values(vmin, vmax)
#    2277
#    2278     def tick_values(self, vmin, vmax):
#
# /usr/local/anaconda3/envs/wa-dev/lib/python3.8/site-packages/matplotlib/ticker.py in tick_values(self, vmin, vmax)
#    2282         vmin, vmax = mtransforms.nonsingular(
#    2283             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2284         locs = self._raw_ticks(vmin, vmax)
#    2285
#    2286         prune = self._prune
#
# /usr/local/anaconda3/envs/wa-dev/lib/python3.8/site-packages/matplotlib/ticker.py in _raw_ticks(self, vmin, vmax)
#    2221         if self._nbins == 'auto':
#    2222             if self.axis is not None:
# -> 2223                 nbins = np.clip(self.axis.get_tick_space(),
#    2224                                 max(1, self._min_n_ticks - 1), 9)
#    2225             else:
#
# /usr/local/anaconda3/envs/wa-dev/lib/python3.8/site-packages/matplotlib/axis.py in get_tick_space(self)
#    2531         length = ((ends[1][1] - ends[0][1]) / self.axes.figure.dpi) * 72
#    2532         # Having a spacing of at least 2 just looks good.
# -> 2533         size = self._get_tick_label_size('y') * 2
#    2534         if size > 0:
#    2535             return int(np.floor(length / size))
#
# /usr/local/anaconda3/envs/wa-dev/lib/python3.8/site-packages/matplotlib/axis.py in _get_tick_label_size(self, axis_name)
#    1341         size = tick_kw.get('labelsize',
#    1342                            mpl.rcParams[f'{axis_name}tick.labelsize'])
# -> 1343         return mtext.FontProperties(size=size).get_size_in_points()
#    1344
#    1345     def _copy_tick_props(self, src, dest):
#
# /usr/local/anaconda3/envs/wa-dev/lib/python3.8/site-packages/matplotlib/font_manager.py in __init__(self, family, style, variant, weight, stretch, size, fname)
#     704
#     705         self.set_family(family)
# --> 706         self.set_style(style)
#     707         self.set_variant(variant)
#     708         self.set_weight(weight)
#
# /usr/local/anaconda3/envs/wa-dev/lib/python3.8/site-packages/matplotlib/font_manager.py in set_style(self, style)
#     836         if style is None:
#     837             style = rcParams['font.style']
# --> 838         cbook._check_in_list(['normal', 'italic', 'oblique'], style=style)
#     839         self._slant = style
#     840     set_slant = set_style
#
# KeyboardInterrupt:
